# %% [markdown]
# <a href="https://colab.research.google.com/github/nithyyaa/flyrank-ml-internship/blob/main/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/nithyyaa/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
### My lane: Content Refresh Prioritization

# %% [markdown]
# I want to explore how search and content signals can help prioritize which pages should be reviewed for a possible content refresh. I chose this lane because the starter pipeline already frames the problem around finding declining pages, and the Week 1 results showed that a learned model can rank potentially declining pages much better than a simple hand-written rule.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# I want to improve the decision of which pages should be reviewed first for a possible content refresh. A content/SEO team member would use the ranking to decide which pages deserve attention before spending time updating them. A wrong recommendation can waste time and resources on a page that does not need a refresh, while a missed declining page may delay an opportunity to improve its performance.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
import os
import subprocess
import sys

REPO_URL = "https://github.com/nithyyaa/flyrank-ml-internship.git"
REPO_DIR = "/content/flyrank-ml-internship"

if not os.path.exists(REPO_DIR):
    subprocess.run(["git", "clone", REPO_URL, REPO_DIR], check=True)

os.chdir(REPO_DIR)

print("Working directory:", os.getcwd())
print("Data exists:", os.path.exists("data/raw/content_refresh_anonymized.csv"))
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Rows:", df.shape[0])
print("Columns:", df.shape[1])

corr = df["search_volume"].corr(df["impressions_90d"])
print("Search volume vs impressions correlation:", round(corr, 3))

print("Random forest Precision@50 from Week 1: 0.740")
print("Baseline Precision@50 from Week 1: 0.240")
# Out:
# Working directory: /content/flyrank-ml-internship
# Data exists: True
# Rows: 30000
# Columns: 44
# Search volume vs impressions correlation: 0.001
# Random forest Precision@50 from Week 1: 0.740
# Baseline Precision@50 from Week 1: 0.240

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# My work will provide observed and measured patterns in the available search data. The results will be directional and used for decision-support, such as helping prioritize pages for review. I cannot claim that the observed relationships are causal, that one factor directly causes another, or that the model predicts Google's algorithm or ranking decisions.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
